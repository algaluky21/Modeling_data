# %%
import pandas as pd
import sqlite3
import math
import datetime 
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

from IPython.core.display import display, HTML
display(HTML("<style>div.output_scroll { height: 44em; }</style>"))
# Out:
# <style>div.output_scroll { height: 44em; }</style>

# %%
conn = sqlite3.connect('database.db')

# %%
c = conn.cursor()

# %%
df = pd.read_csv("data_transaksi.csv")
df
# Out:
#         id      tanggal jual   nama customer      kota    provinsi  \
# 0      1.0   1212122020年1月6日   Achmad Yusril  Surabaya  jawa timur
# 1      2.0   1212122020年1月6日  Yanuar Fitrian  Surabaya  jawa timur
# 2      3.0   1212122020年1月6日  Yanuar Fitrian  Surabaya  jawa timur
# 3      4.0   1212122020年1月6日   Aditya Taufiq  Surabaya  jawa timur
# 4      5.0   1212122020年1月6日   Aditya Taufiq  Surabaya  jawa timur
# ..     ...               ...             ...       ...         ...
# 96    97.0  1212122020年10月6日    jasmine Meca  Surabaya  jawa timur
# 97    98.0  1212122020年10月6日        Ana bela  Surabaya  jawa timur
# 98    99.0  1212122020年10月6日        ana bela  Surabaya  jawa timur
# 99   100.0  1212122020年10月6日      rafli Ihza  Surabaya  jawa timur
# 100    NaN               NaN             NaN       NaN         NaN
#
#         nama barang      merk        jenis  harga beli  harga jual  \
# 0       lampu depan       fdr  accessories     10000.0     15000.0
# 1    lampu belakang       fdr  accessories     10000.0     15000.0
# 2        kanvas rem    yanmar          rem     12000.0     16000.0
# 3         oli mesin  yamalube        mesin      9000.0     10000.0
# 4            rantai   castrol        mesin      9000.0     10000.0
# ..              ...       ...          ...         ...         ...
# 96             skok  kawasaki         skok      1747.0      2047.0
# 97             skok  kawasaki         skok      1748.0      2048.0
# 98             skok  kawasaki         skok      1749.0      2049.0
# 99             skok  kawasaki         skok      1750.0      2050.0
# 100             NaN       NaN          NaN         NaN         NaN
#
#      jumlah beli
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0
# ..           ...
# 96           1.0
# 97           1.0
# 98           1.0
# 99           1.0
# 100          NaN
#
# [101 rows x 11 columns]

# %%
kota = []
pelanggan = []
barang = []
